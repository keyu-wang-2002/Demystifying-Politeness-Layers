# %%
## paragraph-level

import matplotlib.pyplot as plt

# para 1B
para_1B_base = 0.03

para_1B = [
    -0.13, 0.35, -0.01, 0.0, 
    0.06, -0.01, 0.02, 0.04, 
    0.01, -0.00, 0.06, 0.31, 
    0.12, 0.09, 0.05, 0.36
]

para_1B_layers = list(range(len(para_1B)))


# para 3B
para_3B_base = 0.09

para_3B = [
    -0.02, 0.17, 0.25, 0.28, 0.01, 
    0.24, 0.04, 0.07, 0.30, 0.04, 
    0.3, 0.22, 0.24, 0.30, 0.32, 
    0.19, 0.34, 0.27, 0.38, 0.34, 
    0.13, 0.344, 0.05, 0.31, 0.37
]

para_3B_layers = list(range(len(para_3B)))


# para 3B
para_8B_base = 0.256

para_8B = [
    -0.02, -0.04, 0.34, 0.30, 0.26, 0.30, 0.24, 0.01, 
    0.23, 0.44, 0.40, 0.33, 0.03, 0.01, 0.09, 0.29, 
    0.278, 0.0, 0.43, 0.27, 0.35, 0.10, 0.39, 0.35, 
    0.44, 0.22, 0.33, 0.37, 0.25, 0.41, 0.42, 0.54]


para_8B_layers = list(range(len(para_8B)))

# ---- plot ----
fig, axes = plt.subplots(1, 3, figsize=(15, 3), sharey=False)


ax = axes[0]
ax.bar(para_1B_layers, para_1B, color='skyblue', edgecolor='k') #, label=r'$\Delta P^{(\ell)}$'
ax.axhline(para_1B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(a) LLaMA3.2-1B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Paragraph-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 1.0)
ax.legend()


ax = axes[1]
ax.bar(para_3B_layers, para_3B, color='navajowhite', edgecolor='k')
ax.axhline(para_3B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.2-3B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Paragraph-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 1.0)
ax.legend()


ax = axes[2]
ax.bar(para_8B_layers, para_8B, color='khaki', edgecolor='k')
ax.axhline(para_8B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.1-8B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Paragraph-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 1.0)
ax.legend()


plt.tight_layout()
plt.show()
# Out:
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\1344217678.py:55: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\1344217678.py:65: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\1344217678.py:75: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
## sentence-level

import matplotlib.pyplot as plt

# sent 1B
sent_1B_base = 0.08

sent_1B = [0, 0.08, 0, 0.05, 0, 0.06, 0, 0.05, 0, 0.081632653, 0.07, 0, 0.07, 0, 0.03, 0]


sent_1B_layers = list(range(len(para_1B)))


# sent 3B
sent_3B_base = 0.05

sent_3B = [0, 0.06, 0.06, 0, 0.03, 0, 0.04, 0, 0.04, 0, 0.07, 0, 0.04, 0, 0.04, 0, 0.05, 0, 0.04, 0, 0, 0.04, 0, 0.07, 0]


sent_3B_layers = list(range(len(sent_3B)))


# sent 3B
sent_8B_base = 0.05

sent_8B = [0, 0.04, 0, 0, 0.06, 0, 0.08, 0, 0.06, 0, 0.07, 0, 0.03, 0, 0.04, 0, 0.02, 0, 0.12, 0, 0, 0.04, 0, 0.05, 0, 0.06, 0, 0.03, 0, 0.05, 0.03, 0.04]



sent_8B_layers = list(range(len(sent_8B)))

# ---- plot ----
fig, axes = plt.subplots(1, 3, figsize=(15, 3), sharey=False)


ax = axes[0]
ax.bar(sent_1B_layers, sent_1B, color='skyblue', edgecolor='k') #, label=r'$\Delta P^{(\ell)}$'
ax.axhline(sent_1B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(a) LLaMA3.2-1B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Sentence-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


ax = axes[1]
ax.bar(sent_3B_layers, sent_3B, color='navajowhite', edgecolor='k')
ax.axhline(sent_3B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.2-3B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Sentence-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


ax = axes[2]
ax.bar(sent_8B_layers, sent_8B, color='khaki', edgecolor='k')
ax.axhline(sent_8B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.1-8B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('Sentence-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


plt.tight_layout()
plt.show()
# Out:
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\267365031.py:43: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\267365031.py:53: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\267365031.py:63: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
## word-level

import matplotlib.pyplot as plt

# word 1B
word_1B_base = 0.06

word_1B = [0, 0.06, 0, 0.12, 0, 0.08, 0, 0.05, 0, 0.102040816, 0.1, 0, 0.09, 0, 0.04, 0]


word_1B_layers = list(range(len(para_1B)))


# word 3B
word_3B_base = 0.08

word_3B = [0, 0.08, 0.04, 0, 0.06, 0, 0.04, 0, 0.04, 0, 0.024, 0, 0.06, 0, 0.06, 0, 0.06, 0, 0.04, 0, 0, 0.06, 0, 0.04, 0]



word_3B_layers = list(range(len(word_3B)))


# word 3B
word_8B_base = 0.04

word_8B = [0, 0.08, 0, 0, 0.04, 0, 0.1, 0, 0.04, 0, 0.06, 0, 0.04, 0, 0.04, 0, 0.04, 0, 0.04, 0, 0, 0.04, 0, 0.05, 0, 0.1, 0, 0.06, 0, 0.06, 0.02, 0.03]



word_8B_layers = list(range(len(word_8B)))

# ---- plot ----
fig, axes = plt.subplots(1, 3, figsize=(15, 3), sharey=False)


ax = axes[0]
ax.bar(word_1B_layers, word_1B, color='skyblue', edgecolor='k') #, label=r'$\Delta P^{(\ell)}$'
ax.axhline(word_1B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(a) LLaMA3.2-1B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('word-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


ax = axes[1]
ax.bar(word_3B_layers, word_3B, color='navajowhite', edgecolor='k')
ax.axhline(word_3B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.2-3B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('word-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


ax = axes[2]
ax.bar(word_8B_layers, word_8B, color='khaki', edgecolor='k')
ax.axhline(word_8B_base, color='k', linestyle='--', linewidth=1)
ax.set_title('(b) LLaMA3.1-8B')
ax.set_xlabel('Layer Index $\\ell$')
ax.set_ylabel('word-level Politeness $ P^{(\\ell)}$')
ax.set_ylim(0.0, 0.4)
ax.legend()


plt.tight_layout()
plt.show()
# Out:
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\2181277776.py:44: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\2181277776.py:54: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\keyuw\AppData\Local\Temp\ipykernel_30896\2181277776.py:64: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
